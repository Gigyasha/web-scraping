# %%
import time 
import requests, json 
import pandas as pd
import csv       
# enter your api key here 
api_key = "AIzaSyAUXAFbZoGkggTdGf_YrNWFM-F0CXTZ1Sg"
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
#url_geo="https://maps.googleapis.com/maps/api/geocode/json?"
#ur="https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJN1t_tDeuEmsRUsoyG83frY4&fields=name,rating,formatted_phone_number&key=YOUR_API_KEY"
# The text string on which to search 
#query = input('Search query: ') 
#r = requests.get(url + 'query=' + query +
                        #'&key=' + api_key) 
#x = r.json()  

#y = x['results'] 
j=0
head=["name","phone_no","address","type"]

#query_list=["medical stores in ","medical wholesaler in ","medical distributer in "]
#city=["Ajmer","Alwar","Bharatpur","Bhilwara","Banswara","Bikaner","Barmer","Churu","Dausa","Dholpur","Dungarpur","Jaipur","Jaisalmer","Jhunjhunu","Jodhpur","Jhalawar","Karauli","Kota","Nagaur","Pali","Pratapgarh","Sikar","Tonk","Udaipur"]
#state=" Rajasthan"

query=[]
for c in city:
        for qu in query_list:
            query.append(qu+c+state)

query=["medical stores in jaipur rajasthan","medical wholesaler in jaipur rajasthan","medical distributer in jaipur rajasthan"]
            
print(len(query))
for q in query:
    with open('rajasthan_data_jaipur.csv', mode='a+',encoding="UTF-8",newline="") as file:
        writer1 = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        writer1.writerow(head)
        r = requests.get(url + 'query=' + q + '&key=' + api_key) 
        # keep looping upto length of y 
        while True:
            x = r.json()  
            #print("XX",x["next_page_token"])
            y = x['results'] 
            #print("YY",y)
            for i in range(len(y)):   
                    time.sleep(2)
                    place_name=y[i]['name']
                    place_address=y[i]['formatted_address']
                    try:
                        place_id =y[i]['place_id']
                    except KeyError:
                        place_id =None
                    if place_id is not None:
                        ur="https://maps.googleapis.com/maps/api/place/details/json?place_id="+place_id+"&fields=name,rating,formatted_address,formatted_phone_number&key=AIzaSyBm8iBkpo_l1x7_8XqyPdcaR86nW7k2-Rs"
                        res = requests.get(ur) 
                        x_data = res.json()
                        try:
                            print(x_data)
                            y_data = x_data['result'] 
                            #print(y_data)
                        
                            address=y_data["formatted_address"]
                            try:
                                phone=y_data["formatted_phone_number"]
                            except KeyError:
                                phone=None

                            name=y_data["name"]
                            j=j+1
                            print("Place",j)
                            print(name)
                            print(phone)
                            print(address)
                            print(q)
                            writer1.writerow([name,phone,address,query])
                        except Exception as e:
                            print("Error")
                            print(e)
                            continue
                    geometry=y[i]['geometry']
                    loc_cord=geometry['location']
                    lat=loc_cord['lat']
                    long=loc_cord['lng']
                    types=y[i]['types']


            try:
                next_pg=x["next_page_token"]
                print(next_pg)
            except KeyError:
                next_pg = "Null"
                y = x['results'] 
                #print("YY",y)
            if next_pg=="Null":
                break
            else:
                r = requests.get(url+'&key=' + api_key + "&pagetoken="+next_pg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4118ac4e4ba> in <module>
#      25
#      26 query=[]
# ---> 27 for c in city:
#      28         for qu in query_list:
#      29             query.append(qu+c+state)
#
# NameError: name 'city' is not defined
