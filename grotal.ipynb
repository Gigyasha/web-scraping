# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


from selenium import webdriver  
from selenium.webdriver.common.keys import Keys  
from selenium.webdriver.chrome.options import Options 
import time
from bs4 import BeautifulSoup
import pandas as pd
import csv
from random import randint
from selenium.webdriver.support.wait import WebDriverWait
 
url="https://www.grotal.com/Ajmer/Pharmaceutical-C193A0P1A0/"

chrome_options = Options()  
chrome_options.add_argument("--headless")  
driver =webdriver.Chrome(executable_path=r'C:\Users\DELL\.wdm\drivers\chromedriver\80.0.3987.106\win32\chromedriver.exe')
driver.get(url)
time.sleep(5)

data_link=[]
try:
    page_bl=driver.find_element_by_class_name("pagination")
    li_tag=page_bl.find_elements_by_tag_name("li")
except Exception as e:
    print("one pg only",e)
    li_tag=["one"]
page=len(li_tag)
print(page)
mobile=None
pg=1
head=["name","phone","mobile","address","category"]
with open('dawa_bazaar_ajmer.csv', mode='a+',encoding="UTF-8",newline="") as file:
    writer1 = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    writer1.writerow(head)
    while pg<=page:
        try:
            url="https://www.grotal.com/Ajmer/Pharmaceutical-C193A0P"+str(pg)+"A0/"
            driver.get(url)
            time.sleep(5)
            elem_list=driver.find_elements_by_class_name("result-row")
            for e in elem_list:
                try:
                    name=None
                    address=None
                    phone=None
                    #print(e.text)
                    title_tag=e.find_element_by_class_name("title")
                    name=(title_tag.find_element_by_class_name("cursor").text).strip()
                    address=(e.find_element_by_class_name("address").text).strip()
                    phone=(e.find_element_by_class_name("ph-no").text).strip()
                    cat=(e.find_element_by_class_name("desc").text).strip()
                    print("NAME",name)
                    print("PHONE",phone)
                    print("ADDRESS",address)
                    print("CATEGORY",cat)

                    
                    
                except Exception as e:
                    print("NO A TAG",e)
                    continue
            pg=pg+1
            print("PAGE--",pg," COMPLETE")
        except Exception as e:
            print("page problem",e)
            continue
