# %%
import time 
import requests, json 
import pandas as pd
import csv       
# enter your api key here 
api_key = "AIzaSyBm8iBkpo_l1x7_8XqyPdcaR86nW7k2-Rs"
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
url_geo="https://maps.googleapis.com/maps/api/geocode/json?"
ur="https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJN1t_tDeuEmsRUsoyG83frY4&fields=name,rating,formatted_phone_number&key=YOUR_API_KEY"
# The text string on which to search 
#query = input('Search query: ') 
#r = requests.get(url + 'query=' + query +
                        #'&key=' + api_key) 
#x = r.json()  

#y = x['results'] 
j=0
head=["name","phone_no","address","type"]



query=["doctors in jaipur"]

print(len(query))
for q in query:
    with open('output.csv', mode='a+',encoding="UTF-8",newline="") as file:
        writer1 = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        writer1.writerow(head)
        r = requests.get(url + 'query=' + q + '&key=' + api_key) 
        # keep looping upto length of y 
        while True:
            x = r.json()  
            #print("XX",x["next_page_token"])
            y = x['results'] 
            #print("YY",y)
            for i in range(len(y)):   
                    time.sleep(2)
                    place_name=y[i]['name']
                    place_address=y[i]['formatted_address']
                    try:
                        place_id =y[i]['place_id']
                    except KeyError:
                        place_id =None
                    if place_id is not None:
                        ur="https://maps.googleapis.com/maps/api/place/details/json?place_id="+place_id+"&fields=name,rating,formatted_address,formatted_phone_number&key=AIzaSyBm8iBkpo_l1x7_8XqyPdcaR86nW7k2-Rs"
                        res = requests.get(ur) 
                        x_data = res.json()
                        try:
                            print(x_data)
                            y_data = x_data['result'] 
                            #print(y_data)
                        
                            address=y_data["formatted_address"]
                            try:
                                phone=y_data["formatted_phone_number"]
                            except KeyError:
                                phone=None

                            name=y_data["name"]
                            j=j+1
                            print("Place",j)
                            print(name)
                            print(phone)
                            print(address)
                            print(q)
                            writer1.writerow([name,phone,address,query])
                        except KeyError as e:
                            print("Error")
                            print(e)
                            continue
                    geometry=y[i]['geometry']
                    loc_cord=geometry['location']
                    lat=loc_cord['lat']
                    long=loc_cord['lng']
                    types=y[i]['types']


            try:
                next_pg=x["next_page_token"]
                print(next_pg)
            except KeyError:
                next_pg = "Null"
                y = x['results'] 
                #print("YY",y)
            if next_pg=="Null":
                break
            else:
                r = requests.get(url+'&key=' + api_key + "&pagetoken="+next_pg)
# Out:
# 1

# %%
ur="https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJObCEqL-1bTkRo-ekct5N_n8&fields=name,rating,formatted_address,formatted_phone_number&key=AIzaSyBm8iBkpo_l1x7_8XqyPdcaR86nW7k2-Rs"
res = requests.get(ur) 
x_data = res.json()  
y_data = x_data['result'] 
print(y_data["formatted_address"])
print(y_data["formatted_phone_number"])
print(y_data["name"])
# Out:
# {'formatted_address': '23, Opposite Khetan Hospital, Shriram Colony, Siksr Road, Siksr Road, Ganpati Nagar, Jaipur, Rajasthan 302015, India', 'formatted_phone_number': '0141 223 0112', 'name': 'Vinayak Medical Store'}

# %%
import time 
import requests, json 
          
# enter your api key here 
api_key = "AIzaSyBm8iBkpo_l1x7_8XqyPdcaR86nW7k2-Rs"
  
# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
#url_geo="httpsm://maps.googleapis.com/maps/api/geocode/json?"
  
# The text string on which to search 
query = input('Search query: ') 
r= requests.get(url + 'query=' + query +
                        '&key=' + api_key) 
x = r.json()  
#places=[]
#results =  res.json()
#places.extend(results['results'])
#time.sleep(2)
#while "next_page_token" in results:
 #   params['pagetoken'] = results['next_page_token'],
  #  res = requests.get(endpoint_url, params = params)
   # results = json.loads(res.content)
    #print(results['results'])
    #time.sleep(2)
y = x['results'] 
fields= ['name', 'formatted_address', 'international_phone_number', 'website', 'rating', 'review']
# keep looping upto length of y 
for i in range(len(y)):   
    
    time.sleep(2)
    place_name=y[i]['name']
    place_address=y[i]['formatted_address']
    geometry=y[i]['geometry']
    loc_cord=geometry['location']
    lat=loc_cord['lat']
    long=loc_cord['lng']
    rating=y[i]['rating']
    types=y[i]['types']
    place_id=y[i]['place_id']
    
    endpoint_url = "https://maps.googleapis.com/maps/api/place/details/json"
    params = {'placeid': place_id,'fields': ",".join(fields),'key':api_key}
    res = requests.get(endpoint_url, params = params)
    details =  json.loads(res.content)
    #details=place_details['result']
    print(details)
    try:
        website = details['result']['website']
    except KeyError:
        website = ""
 
    try:
        name = details['result']['name']
    except KeyError:
        name = ""
 
    try:
        address = details['result']['formatted_address']
    except KeyError:
        address = ""
 
    try:
        phone_number = details['result']['international_phone_number']
    except KeyError:
        phone_number = ""
 
    try:
        reviews = details['result']['reviews']
    except KeyError:
        reviews = []
    print("===================PLACE===================")
    print("Name:", name)
    print("Address:", address)
    print("LATITUDE & LONGITUDE",lat,long)  #from above url
    print("RATING",rating)        #from above url
    print("TYPES",types)          #from above url
    print("Website:", website)
    print("Phone Number", phone_number)
    
    print("==================REVIEWS==================")
    for review in reviews:
        author_name = review['author_name']
        rating = review['rating']
        text = review['text']
        duration= review['relative_time_description']
        profile_photo = review['profile_photo_url']
        print("Author Name:", author_name)
        print("Rating:", rating)
        print("Text:", text)
        print("Time:", duration)
        print("Profile photo:", profile_photo)
        print("-----------------------------------------")
# Out:
# Search query: stock market companies in usa

# %%
states=["Ajmer","Alwar","Bharatpur","Bhilwara","Banswara","Bikaner","Barmer","Churu","Dausa","Dholpur","Dungarpur","Jaipur","Jaisalmer","Jhunjhunu","Jodhpur","Jhalawar","Karauli","Kota","Nagaur","Pali","Pratapgarh","Sikar","Tonk","Udaipur"]
